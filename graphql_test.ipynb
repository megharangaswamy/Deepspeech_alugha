# %%
#1,2
import json
import wget 
import os
import sys
import urllib
#import urllib2
import requests
import pandas as pd
pd.options.display.max_colwidth = 100
import numpy as np
import json, ast
from pprint import pprint
#3

import os
import ffmpy
from pydub import AudioSegment
import subprocess
from pydub.utils import make_chunks
#import scipy.io.wavfile as wav

# %%
df = pd.DataFrame(columns=['A','B','C','D','E','F'])
with open('/home/megha/1_audio_current/0_curl_output_dubbr_final.txt', 'r') as f:#file name which has json data - check that number
    my_json = json.load(f)
for i in range(len(my_json['data']['videos'])):
    #print(len(my_json['data']['videos'][i]['dubbrSegments']))
    if len(my_json['data']['videos'][i]['dubbrSegments'])>0:    
        audio_id = my_json['data']['videos'][i]['id']
        dubbrSeg_start_array = []
        dubbrSeg_duration_array = []
        segmentId_array = []
        for j in range(len(my_json['data']['videos'][i]['dubbrSegments'])):
            dubbrSeg_start = my_json['data']['videos'][i]['dubbrSegments'][j]['start']
            dubbrSeg_duration =  my_json['data']['videos'][i]['dubbrSegments'][j]['duration']
            k= 0
            segmentId = my_json['data']['videos'][i]['dubbrSegments'][j]['meta'][k]['id']
            dubbrSeg_start_array.append(dubbrSeg_start)
            dubbrSeg_duration_array.append(dubbrSeg_duration)
            segmentId_array.append(segmentId)
            segmentId_array = ast.literal_eval(json.dumps(segmentId_array)) # to remove u'
            #print('segmentId = ' , segmentId)
            #print('start =', dubbrSeg_start)
            #print('duration',dubbrSeg_duration)
        track = my_json['data']['videos'][i]['track']
        langCode = track['langCode']
        trackId = track['id']
        print('--------------------------------------------------------')
        print(audio_id)
        print(dubbrSeg_start_array)
        print(dubbrSeg_duration_array)
        print(segmentId_array)
        print(trackId)
        print(langCode)
        print('--------------------------------------------------------')
        df2 = pd.DataFrame([[audio_id,dubbrSeg_start_array,dubbrSeg_duration_array,segmentId_array,trackId,langCode]], columns=list('ABCDEF'))
        df = df.append(df2)

df = df.rename(index=str, columns={"A": "audio_id", "B": "dubbrSegemnt_start","C" : "dubbrSegemnt_duration","D" : "segemntId","E" : "trackId","F": "langCode"})
# Out:
# --------------------------------------------------------
# 64e7730d-c150-11e6-ac9e-8b7e42960c7b
# [0]
# [10000]
# ['21804740-4e08-11e8-b907-931749d56bdb']
# 64f292a5-c150-11e6-bbf4-81aee5f31e7a
# eng
# --------------------------------------------------------
# --------------------------------------------------------
# e2aabee7-663f-11e7-a01a-c3cae061c315
# [0, 15674]
# [8389, 10000]
# ['b674fd10-695f-11e8-87dd-93f5b25c0d12', '0b1cbdd0-6960-11e8-87dd-93f5b25c0d12']
# e2ac1e31-663f-11e7-b7dc-01b46c33399e
# eng
# --------------------------------------------------------
# --------------------------------------------------------
# 6db71f65-76bd-11e7-bf45-d74dc99cbf10
# [4055, 12411]
# [8355, 10000]
# ['7854ace0-371b-11e8-acc5-214ed5490e73', 'ab359960-4e10-11e8-b907-931749d56bdb']
# 6db72031-76bd-11e7-a299-abf33edccd69
# eng
# --------------------------------------------------------
# --------------------------------------------------------
# 5c0187a7-c309-11e7-be27-290288ad4ec6
# [0]
# ...

# %%
df
# Out:
#                                audio_id  \
# 0  64e7730d-c150-11e6-ac9e-8b7e42960c7b
# 0  e2aabee7-663f-11e7-a01a-c3cae061c315
# 0  6db71f65-76bd-11e7-bf45-d74dc99cbf10
# 0  5c0187a7-c309-11e7-be27-290288ad4ec6
# 0  4906cd71-dded-11e7-aed6-cd07e3b2b5de
# 0  83c789ee-4e08-11e8-a07a-1bae606a4562
# 0  5964353c-5366-11e8-b496-af25df1aa3fb
#
#                                                                                     dubbrSegemnt_start  \
# 0                                                                                                  [0]
# 0                                                                                           [0, 15674]
# 0                                                                                        [4055, 12411]
# 0                                                                                                  [0]
# 0  [847, 3567, 6255, 11522, 15141, 19246, 30999, 33011, 35191, 37204, 39849, 42326, 44972, 49646, 5...
# ...

# %%
#Reading Deepspeech output csv file
df_DS_output= pd.read_csv('/media/home/megha/2_deepspeech_currrent/DeepSpeech/wave_files_audio_split/deepspeech_prediction_output.csv', sep=',')
df_DS_output["segmentMetaId"] = "" #adding empty column
df_DS_output = df_DS_output[['audio_segments','audio_segment_transcript','segmentMetaId']]#ignoring unwanted coulmn
df_DS_output
# Out:
#                                                                    audio_segments  \
# 0   4906cd71-dded-11e7-aed6-cd07e3b2b5de_0ba4ec20-a130-11e8-aec1-6154de980aa1.wav
# 1   4906cd71-dded-11e7-aed6-cd07e3b2b5de_273afec0-a130-11e8-aec1-6154de980aa1.wav
# 2   4906cd71-dded-11e7-aed6-cd07e3b2b5de_2dc007c1-a12d-11e8-aec1-6154de980aa1.wav
# 3   4906cd71-dded-11e7-aed6-cd07e3b2b5de_393cfb01-a130-11e8-aec1-6154de980aa1.wav
# 4   4906cd71-dded-11e7-aed6-cd07e3b2b5de_49205d01-a130-11e8-aec1-6154de980aa1.wav
# 5   4906cd71-dded-11e7-aed6-cd07e3b2b5de_59c67a21-a12d-11e8-aec1-6154de980aa1.wav
# 6   4906cd71-dded-11e7-aed6-cd07e3b2b5de_5bdbe540-a130-11e8-aec1-6154de980aa1.wav
# 7   4906cd71-dded-11e7-aed6-cd07e3b2b5de_6e6ba292-a130-11e8-aec1-6154de980aa1.wav
# 8   4906cd71-dded-11e7-aed6-cd07e3b2b5de_70851411-a12d-11e8-aec1-6154de980aa1.wav
# 9   4906cd71-dded-11e7-aed6-cd07e3b2b5de_74732c41-a12f-11e8-aec1-6154de980aa1.wav
# ...

# %%
for i in range(len(df_DS_output['audio_segments'])):
    segmentMetaId = df_DS_output['audio_segments'][i].split('_')[0]#you are taking 0 bcz u decided that you will save segmentmetaId as the first part in the file naming.
    df_DS_output['segmentMetaId'][i] = segmentMetaId
df_DS_output
# Out:
#                                                                    audio_segments  \
# 0   4906cd71-dded-11e7-aed6-cd07e3b2b5de_0ba4ec20-a130-11e8-aec1-6154de980aa1.wav
# 1   4906cd71-dded-11e7-aed6-cd07e3b2b5de_273afec0-a130-11e8-aec1-6154de980aa1.wav
# 2   4906cd71-dded-11e7-aed6-cd07e3b2b5de_2dc007c1-a12d-11e8-aec1-6154de980aa1.wav
# 3   4906cd71-dded-11e7-aed6-cd07e3b2b5de_393cfb01-a130-11e8-aec1-6154de980aa1.wav
# 4   4906cd71-dded-11e7-aed6-cd07e3b2b5de_49205d01-a130-11e8-aec1-6154de980aa1.wav
# 5   4906cd71-dded-11e7-aed6-cd07e3b2b5de_59c67a21-a12d-11e8-aec1-6154de980aa1.wav
# 6   4906cd71-dded-11e7-aed6-cd07e3b2b5de_5bdbe540-a130-11e8-aec1-6154de980aa1.wav
# 7   4906cd71-dded-11e7-aed6-cd07e3b2b5de_6e6ba292-a130-11e8-aec1-6154de980aa1.wav
# 8   4906cd71-dded-11e7-aed6-cd07e3b2b5de_70851411-a12d-11e8-aec1-6154de980aa1.wav
# 9   4906cd71-dded-11e7-aed6-cd07e3b2b5de_74732c41-a12f-11e8-aec1-6154de980aa1.wav
# ...

# %%
#my function definition

def run_query(query,variables):
    # A simple function to use requests.post to make the API call. Note the json= section.
    request = requests.post("https://ci.alugha.com/graphql",json={"query":query, "variables":variables}, headers={"Authorization" : Authorization })
    if request.status_code == 200:
        return request.json()
    else:
        raise Exception("Query failed to run by returning code of {}. {}".format(request.status_code, query))
        
        
query = """mutation($segmentMetaId: ID!,$accessKey: String!,$data: UpdateSegmentMetaInput!){updateSegmentMeta(segmentMetaId:$segmentMetaId,data:$data, accessKey: $accessKey){id}}"""
variables= {"segmentMetaId": "c6834a02-b75b-11e8-8546-230a8e40bcf7","data": {"text":  "I............... am trying for second time"},"accessKey": "mrDepUi6iWbrU8JL6RnEcgBPASIdhqudrSeFnYxynGJ1HxVy2lF7djznSR3AGHLF"}
Authorization = "Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJleHAiOjE1MzkzMjc4OTUsImlhdCI6MTUzODcyMzA5NSwianRpIjoiZjZlMzMyNzYtYzg2Yy0xMWU4LWJjOGEtZWYzM2JjYjFhMDFmIiwicm9sZSI6MSwidXNlcmlkIjoiYTM4NDdkMmQtYzMwMi0xMWU3LWE0ZjUtYzllN2E1MmViZTY5In0.Ii_T3rF5fbzvqwtshW-S1mNYRI2jUz5YOHeKJWjbPyE"
result = run_query(query,variables) # Execute the query
result
# Out:
# {u'data': {u'updateSegmentMeta': {u'id': u'c6834a02-b75b-11e8-8546-230a8e40bcf7'}}}

# %%
#my function defination
def run_query(query): # A simple function to use requests.post to make the API call. Note the json= section.
    request = requests.post("https://ci.alugha.com/graphql", json={"query": query})#, headers=headers)
    if request.status_code == 200:
        return request.json()
    else:
        raise Exception("Query failed to run by returning code of {}. {}".format(request.status_code, query))
        
query = """
{  updateSegmentMeta(segmentMetaId:"c6834a02-b75b-11e8-8546-230a8e40bcf7",data:{
  text: "I am trying for secind time"}, accessKey: "mrDepUi6iWbrU8JL6RnEcgBPASIdhqudrSeFnYxynGJ1HxVy2lF7djznSR3AGHLF"
  )
  {
    id
    trackId
    track{langCode}
    text
    assetId
    asset{
      name
    }
    waveformValues
   
  }
}
"""
        
        
result = run_query(query) # Execute the query
result

# %%
#my function defination
def run_query(query): # A simple function to use requests.post to make the API call. Note the json= section.
    request = requests.post("https://ci.alugha.com/graphql", json={"query": query})#, headers=headers)
    if request.status_code == 200:
        return request.json()
    else:
        raise Exception("Query failed to run by returning code of {}. {}".format(request.status_code, query))
        
query = """
{
  videos(minLanguageCount: 1, limit: 5000, createdAfter: "2000-01-01T00:00:00Z") {
    id
    dubbrSegments {
      id
      start
      duration
      meta {
        id
        track {
          langCode
        }
        text
      }
    }
  }
}
"""
        
        
result = run_query(query) # Execute the query
result
# Out:
# {u'data': {u'videos': [{u'dubbrSegments': [{u'duration': 10000,
#       u'id': u'06bbd180-c622-11e8-adfa-194c321c6806',
#       u'meta': [{u'id': u'06bc1fa1-c622-11e8-adfa-194c321c6806',
#         u'text': u'',
#         u'track': {u'langCode': u'deu'}},
#        {u'id': u'06bc1fa0-c622-11e8-adfa-194c321c6806',
#         u'text': u'',
#         u'track': {u'langCode': u'nld'}}],
#       u'start': 0},
#      {u'duration': 10000,
#       u'id': u'07b525a0-c622-11e8-adfa-194c321c6806',
#       u'meta': [{u'id': u'07b54cb1-c622-11e8-adfa-194c321c6806',
#         u'text': u'',
#         u'track': {u'langCode': u'deu'}},
#        {u'id': u'07b54cb0-c622-11e8-adfa-194c321c6806',
#         u'text': u'',
#         u'track': {u'langCode': u'nld'}}],
#       u'start': 10001},
#      {u'duration': 10000,
#       u'id': u'082fd3e0-c622-11e8-adfa-194c321c6806',
#       u'meta': [{u'id': u'082ffaf0-c622-11e8-adfa-194c321c6806',
#         u'text': u'',
#         u'track': {u'langCode': u'nld'}},
# ...

# %%
https://stackoverflow.com/questions/48693825/making-a-graphql-mutation-from-my-python-code-getting-error
    

https://medium.com/graphql-mastery/graphql-quick-tip-how-to-pass-variables-into-a-mutation-in-graphiql-23ecff4add57


https://medium.com/the-graphqlhub/graphql-tour-variables-58c6abd10f56
